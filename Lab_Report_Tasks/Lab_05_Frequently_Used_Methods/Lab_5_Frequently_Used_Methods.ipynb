# %% [markdown]
# <!-- ================= LAB REPORT STYLE ================= -->
# <style>
# body {
#     font-family: "Segoe UI", Arial, sans-serif;
#     line-height: 1.6;
# }
# .center-title {
#     text-align: center;
#     font-weight: bold;
#     color: #ffffffff;
# }
# .sub-title {
#     text-align: center;
#     font-size: 14px;
#     color: #f0f0f0ff;
# }
# </style>
# <!-- ================= END STYLE ================= -->
# <p class="center-title">UNIVERSITY OF ENGINEERING AND TECHNOLOGY PESHAWAR</p>
# <p class="center-title">Jalozai Campus</p>
# <p class="sub-title">
# <b>Course:</b> Introduction to AI Programming <br>
# <b>Lab No:</b> 05 <br>
# <b>Lab Title:</b> Frequently Used Methods <br>
# <b>Instructor:</b> Irshad Ullah  <br>
# <b>Student:</b> Syed Abdur Rahman
# </p>
#
# ---
#
# <center>
#
# # **Lab Report Tasks**
#
# </center>
#
# ## **Aim of the Lab**
#
# The aim of this experiment is to understand and apply the built-in `sum()` function in Python to calculate total values from a list. The experiment focuses on finding the **total power consumed by electrical components** and determining the **equivalent resistance of resistors connected in series** by adding their respective values.
#
# ### **Tasks**
#
# The built-in `sum()` function is used to add all numerical values in a list.
#
# 1. The power consumed by individual components is stored in a list.
#    Calculate the **total power consumed** by adding all the readings using the `sum()` function.
#
# 2. A list contains the resistance values of resistors connected in **series**.
#    Find the **equivalent resistance** by summing all resistance values.

# %%
#  Total power consumed
power = [10, 15, 20, 5]
total_power = sum(power)
print("Total Power:", total_power)
# Out:
# Total Power: 50

# %%
#  Equivalent resistance
resistances = [5, 10, 15]
equiv_resistance = sum(resistances)
print("Equivalent Resistance:", equiv_resistance)
# Out:
# Equivalent Resistance: 30

# %% [markdown]
# ## **Conclusion of the Lab**
#
# In this experiment, the `sum()` function was successfully used to calculate the total of numerical values stored in a list. The total power consumption and equivalent series resistance were accurately determined using list data. This lab demonstrated the simplicity and effectiveness of Python’s built-in functions and reinforced their practical application in electrical and circuit-related calculations.

# %% [markdown]
# -----------
# --------
