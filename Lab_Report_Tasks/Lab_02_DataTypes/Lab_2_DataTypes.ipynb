# %% [markdown]
# <!-- ================= LAB REPORT STYLE ================= -->
# <style>
# body {
#     font-family: "Segoe UI", Arial, sans-serif;
#     line-height: 1.6;
# }
#
# .center-title {
#     text-align: center;
#     font-weight: bold;
#     color: #ffffffff;
# }
#
# .sub-title {
#     text-align: center;
#     font-size: 14px;
#     color: #f0f0f0ff;
# }
#
# h2 {
#     color: #2c3e50;
#     margin-top: 25px;
# }
#
#
#
# </style>
# <!-- ================= END STYLE ================= -->
#
# <p class="center-title">UNIVERSITY OF ENGINEERING AND TECHNOLOGY PESHAWAR</p>
# <p class="center-title">Jalozai Campus</p>
#
# <p class="sub-title">
# <b>Course:</b> Introduction to AI Programming <br>
# <b>Lab No:</b> 02 <br>
# <b>Lab Title:</b> Data Types <br>
# <b>Instructor:</b> Irshad Ullah  <br>
# <b>Student:</b> Syed Abdur Rahman
# </p>
#
#
#
#
#
# ---

# %% [markdown]
# <center>
#
# # **Lab Report Tasks**
#
# </center>
#
# ## **Aim of the Lab**
#
# The aim of this laboratory experiment is to calculate the **total impedance** of an electrical circuit by adding multiple complex impedances. The experiment focuses on determining the **real (resistive)** and **imaginary (reactive)** components of the total impedance. Additionally, the **magnitude** and **phase angle** of the total impedance are calculated using the `abs()` and `cmath.phase()` functions to analyze the AC circuit behavior.
#
# ## Task: Total Impedance
#
# i. Add the three impedances.
#
# ii. Print real part (resistive) and imaginary part (reactive).
#
# iii. Print magnitude and phase angle (use abs() and cmath.phase()).

# %%
import cmath
import math

# Given circuit parameters
R = 50
L = 0.1
C = 100e-6
f = 60
w = 2 * math.pi * f

# %%
# Impedances
Z_R = complex(R, 0)
Z_L = complex(0, w * L)
Z_C = complex(0, -1 / (w * C))

# %%
# Total impedance
Z_total = Z_R + Z_L + Z_C

print("Total Impedance:", Z_total)
# Out:
# Total Impedance: (50+11.173287994428293j)

# %%
# Real and imaginary parts
print("Resistive Part (Real):", Z_total.real)
print("Reactive Part (Imag):", Z_total.imag)
# Out:
# Resistive Part (Real): 50.0
# Reactive Part (Imag): 11.173287994428293

# %%
# Magnitude & Phase
print("Magnitude:", abs(Z_total))
print("Phase (radians):", cmath.phase(Z_total))
# Out:
# Magnitude: 51.23321544278121
# Phase (radians): 0.2198536515889822

# %% [markdown]
# ## **Conclusion of the Lab**
#
# In this laboratory experiment, the total impedance of the circuit was successfully determined by adding the individual impedances using complex number arithmetic. The **real part** of the total impedance represented the resistive component, while the **imaginary part** represented the reactive component. The **magnitude** and **phase angle** were also calculated, providing a complete understanding of the circuit’s impedance characteristics. This lab enhanced practical understanding of impedance analysis in AC circuits.

# %% [markdown]
# ------------
# ----------
